# %% [markdown]
# # 1. Setup & Imports

# %%
# Adjust working directory if needed
import os
os.chdir("path/to/traderzclient")

from accounts import Accounts
from pprint import pprint

# %% [markdown]
# # 2. Login to Traderz API

# %%
# Initialize the Accounts object
acc = Accounts(
    email="example@gmail.com",
    password="password"
)

# %% [markdown]
# ✔️ If login succeeds, tokens will be stored inside acc.

# %% [markdown]
# # 3. List Available Trading Accounts

# %%
accounts = acc.list_accounts()
pprint(accounts)

# %% [markdown]
# # 4. Select a Trading Account

# %%
acc.select_account(trading_account_id="YOUR_ACCOUNT_ID")
pprint(acc.get_selected_account())

# %% [markdown]
# ✔️ After selection, all other modules (Market, Orders, Positions) will use this account.

# %% [markdown]
# # 5. Retrieve Auth Headers for Manual API Calls

# %%
headers = acc.get_auth_headers()
pprint(headers)

# %% [markdown]
# Useful if you want to call endpoints manually.

# %% [markdown]
# # 6. Quick Check: Selected Account

# %%
acc.get_selected_account()
