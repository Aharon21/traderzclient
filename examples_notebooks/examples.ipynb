# %% [markdown]
# # Full script using client main package

# %%
# ----------------------------
# Imports
# ----------------------------
# Adjust working directory if needed
import os
#os.chdir("path/to/traderzclient")
os.chdir("/Users/elbezaharon/Downloads/traderZ backend/traderz/traderzclient")
from client import TraderzClient
from pprint import pprint

# ----------------------------
# 1️⃣ Login & Select Account
# ----------------------------
EMAIL = "aharon.elbez@ensae.fr"
PASSWORD = "Joshuaelbez1!"

client = TraderzClient(email=EMAIL, password=PASSWORD)
print("✅ Logged in! Token:", client.accounts.token)

# List all trading accounts
print("\n📄 Trading accounts:")
for acc in client.accounts.list_accounts():
    print(f"{acc['tradingAccountId']} - {acc['name']}")

# Select a trading account (second one as example)
selected_id = client.accounts.list_accounts()[1]["tradingAccountId"]
client.select_account(selected_id)
print("\n🎯 Selected account:", client.accounts.get_selected_account()["offer"]["name"])

# ----------------------------
# 2️⃣ Market Data
# ----------------------------
print("\n💹 Fetching market data...")

# Get symbols
symbols = client.market.get_symbols()
print("Symbols preview:", [s['symbol'] for s in symbols[:5]])

# Get candlestick data
candles = client.market.get_candles(
    symbol="EURUSD",
    interval="M15",
    start="2025-07-15T00:00:00Z",
    end="2025-07-15T00:15:00Z"
)
print("\nCandles preview:")
pprint(candles['candles'][:3])

# Market Watch for selected symbols
quotes = client.market.market_watch(symbols=["EURUSD", "GBPUSD"])
print("\nMarket Watch quotes:")
pprint(quotes)

# ----------------------------
# 3️⃣ Positions
# ----------------------------
print("\n📊 Open positions:")
open_positions = client.positions.get_open_positions()
pprint(open_positions)

# ----------------------------
# 4️⃣ Orders
# ----------------------------
print("\n📝 Active orders:")
active_orders = client.orders.get_active_orders()
pprint(active_orders)

# Create a pending order
new_order_id = client.orders.create_pending_order(
    instrument="EURUSD",
    order_side="BUY",
    volume=0.01,
    price=1.05,
    type="LIMIT"
)
print("\n✅ New pending order ID:", new_order_id)

# Edit the pending order
updated_order_id = client.orders.edit_pending_order(
    instrument="EURUSD",
    order_id=new_order_id,
    order_side="BUY",
    volume=0.02,
    price_order=1.06,
    sl_price=1.04,
    tp_price=1.08
)
print("✏️ Updated pending order ID:", updated_order_id)

# Cancel the pending order
cancelled_order_id = client.orders.cancel_pending_order(
    instrument="EURUSD",
    order_id=new_order_id,
    order_side="BUY"
)
print("❌ Cancelled pending order ID:", cancelled_order_id)
# Out:
# ✅ Logged in! Token: eyJhbGciOiJIUzI1NiJ9..c0Cx1zBj1XTn-NBR8sh1FDyLQFrRfWOsxRAjYCn32_Y
#
# 📄 Trading accounts:
# 697741 - LAUNCHING COMPETITION_1_LAUNCHING COMPETITION
# 699937 - test payant_1_test payant
# 700594 - training phase_1_Challenge 24h
# 701545 - PREMIUM November 2025 #8_1_PREMIUM November 2025 #8
# 702588 - training phase_1_Challenge 24h
# 701941 - training phase_1_Challenge 24h
# 700585 - training phase_1_Challenge 24h
# 703432 - PREMIUM December 2025 #1_1_PREMIUM December 2025 #1
#
# 🎯 Selected account: test payant_1_test payant
#
# 💹 Fetching market data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
